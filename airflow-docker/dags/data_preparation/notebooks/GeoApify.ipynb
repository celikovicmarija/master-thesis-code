# %%
import pandas as pd
import os
import csv
import re
import cyrtranslit

# %%
def transliterate_serbian(col):
    return cyrtranslit.to_latin(col,'sr')

# %%
path = "C:\\Users\\mace\\OneDrive - Zühlke Engineering AG\\Documents\\master-thesis-code\\geoapify"
filelist = []

for root, dirs, files in os.walk(path):
    for file in files:
        filelist.append(os.path.join(root, file))
        
# for file in filelist:
#     print(str(file).lower())
#     filename=str(file).lower().split('\\')[-1]
#     df=pd.read_csv(file,skiprows=5, error_bad_lines=False)
#         break
        
struktura_list=[a for a in filelist if 'plat' in file.lower()]

# %%
file=filelist.pop()
print(file)
# Out:
# C:\Users\mace\OneDrive - Zühlke Engineering AG\Documents\master-thesis-code\geoapify\places.csv

# %%
filename=str(file).lower().split('\\')[-1]
df=pd.read_csv(file,skiprows=0, error_bad_lines=False)
df.head()
# Out:
# C:\Users\mace\AppData\Local\Temp\ipykernel_16784\3693978423.py:2: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df=pd.read_csv(file,skiprows=0, error_bad_lines=False)
# C:\Users\mace\AppData\Local\Temp\ipykernel_16784\3693978423.py:2: DtypeWarning: Columns (0,1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv(file,skiprows=0, error_bad_lines=False)
#   street_oglasi micro_location_oglasi         name                     city  \
# 0           NaN            Slavkovica  Дебело брдо  Општина Горњи Милановац
# 1   Pirandelova              Mirijevo          NaN                  Београд
# 2   Pirandelova              Mirijevo          NaN                  Београд
# 3   Pirandelova              Mirijevo          NaN                  Београд
# 4   Pirandelova              Mirijevo          NaN                  Београд
#
# ...

# %%
df.fillna('',inplace=True)

# %%
columns=['name','city','county','formatted','address_line1','address_line2']
for col in columns:
    df[col]=df[col].apply(transliterate_serbian)

# %%
pretty_path = "C:\\Users\\mace\\OneDrive - Zühlke Engineering AG\\Documents\\master-thesis-code\\clean\\"
df.to_csv(f"{pretty_path}{filename}",sep=';')

# %%
df.head()
# Out:
#   street_oglasi micro_location_oglasi         name                      city  \
# 0                          Slavkovica  Debelo brdo  Opština Gornji Milanovac
# 1   Pirandelova              Mirijevo                                Beograd
# 2   Pirandelova              Mirijevo                                Beograd
# 3   Pirandelova              Mirijevo                                Beograd
# 4   Pirandelova              Mirijevo                                Beograd
#
#                     county        lon        lat  \
# 0  Moravički upravni okrug  20.262333   44.13815
# 1             Grad Beograd  20.534988  44.780094
# 2             Grad Beograd  20.535073  44.780203
# 3             Grad Beograd  20.535142  44.780227
# 4             Grad Beograd  20.535409  44.779997
#
#                                            formatted    address_line1  \
# 0  Debelo brdo, Opština Gornji Milanovac, Moravič...      Debelo brdo
# ...
