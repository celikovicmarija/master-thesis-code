# %%
import pandas as pd
import os
import csv

# %%
path = "C:\\Users\\mace\\OneDrive - Zühlke Engineering AG\\Documents\\master-thesis-code\\raw data\\Potrošačka korpa\\extracted"
# we shall store all the file names in this list
filelist = []

for root, dirs, files in os.walk(path):
    for file in files:
        # append the file name to the list
        filelist.append(os.path.join(root, file))

for file in filelist:
    if 'struktura' in str(file).lower():
        print(str(file).lower())
        filename=str(file).lower().split('\\')[-1]
        df=pd.read_csv(file,skiprows=5, error_bad_lines=False)
        break

# %%
nazivi=['Hrana i bezalkoholna pića','Alkoholna pića i duvan','Odeća i obuća','Stanovanje,voda,struja,gas i druga goriva','Nameštaj, opremanje domaćinstava i održavanje','Zdravstvo','Transport','Komunikacije','Rekreacija i kultura','Obrazovanje','Restorani i hoteli','Ostala dobra i usluge','Vrednost Korpe-Ukupno']

# %%
struktura_list=[a for a in filelist if 'struktura' in str(file).lower()]

# %%
file=struktura_list.pop()
print(file)
# Out:
# C:\Users\mace\OneDrive - Zühlke Engineering AG\Documents\master-thesis-code\raw data\Potrošačka korpa\extracted\Septembar 2021\Struktura potrosacke korpe septembar 2021.csv

# %%
filename=str(file).lower().split('\\')[-1]
df=pd.read_csv(file,skiprows=5, error_bad_lines=False)
df.rename({'Unnamed: 0':'Element'}, inplace=True,axis=1)
df[['Iznos Nove Prosecne korpe','Procenat Nove Prosecne korpe']]=df['%'].str.split(' ', expand=True)
df[['Iznos Minimalne Potrosacke korpe','Procenat Nove Minimalne korpe']]=df['Unnamed: 2'].str.split(' ', expand=True)
df.drop('%',axis=1,inplace=True)
df.drop('Unnamed: 2',axis=1,inplace=True)
df.drop([16,8,6,5,3],axis=0,inplace=True)
df.iloc[:,0]=nazivi
pretty_path = "C:\\Users\\mace\\OneDrive - Zühlke Engineering AG\\Documents\\master-thesis-code\\raw data\\Potrošačka korpa\\extracted\\clean\\"
df.to_csv(f"{pretty_path}{filename}")
# Out:
# C:\Users\mace\AppData\Local\Temp\ipykernel_3208\2778821394.py:2: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df=pd.read_csv(file,skiprows=5, error_bad_lines=False,sep=';')

# %%
df
# Out:
#                                           Element Iznos Nove Prosecne korpe  \
# 0                       Hrana i bezalkoholna pica                 23.387,36
# 1                          Alkoholna pica i duvan                  3.196,35
# 2                                   Odeca i obuca                  3.082,49
# 4       Stanovanje,voda,struja,gas i druga goriva                 10.651,05
# 7   Namestaj, opremanje domacinstava i odrzavanje                  2.396,00
# 9                                       Zdravstvo                  2.056,97
# 10                                      Transport                  4.779,98
# 11                                   Komunikacije                  1.541,05
# 12                           Rekreacija i kultura                  2.266,38
# 13                                    Obrazovanje                    425,30
# 14                             Restorani i hoteli                    627,27
# 15                          Ostala dobra i usluge                  1.788,41
# 17                          Vrednost Korpe-Ukupno                 56.198,61
#
#    Procenat Nove Prosecne korpe Iznos Minimalne Potrosacke korpe  \
# 0                         41,62                        14.532,69
# 1                          5,69                         1.800,81
# 2                          5,48                         1.185,67
# 4                         18,95                         5.477,38
# 7                          4,26                        1.1253,77
# 9                          3,66                         1.120,27
# 10                         8,51                         1.932,41
# 11                         2,74                          736,,43
# 12                         4,03                           872,78
# 13                         0,76                           109,60
# 14                         1,12                           219,18
# 15                         3,18                           995,44
# 17                       100,00                        30.236,43
#
#    Procenat Nove Minimalne korpe
# 0                          48,06
# 1                           5,96
# 2                           3,92
# 4                          18,12
# 7                           4,15
# 9                           3,71
# 10                          6,39
# 11                          2,44
# 12                          2,89
# 13                          0,36
# 14                          0,72
# 15                          3,29
# 17                       100,00%
