# %%
import pandas as pd
import os
import csv
import re

# %%
path = "C:\\Users\\mace\\OneDrive - Zühlke Engineering AG\\Documents\\master-thesis-code\\raw data\\sorted\\Kurs\\"
filelist = []

for root, dirs, files in os.walk(path):
    for file in files:
        filelist.append(os.path.join(root, file))
        
for file in filelist:
    if 'plat' in str(file).lower():
        print(str(file).lower())
        filename=str(file).lower().split('\\')[-1]
        df=pd.read_csv(file,skiprows=5, error_bad_lines=False)
        break
        
struktura_list=[a for a in filelist]

# %%
file=struktura_list.pop()
print(file)
# Out:
# C:\Users\mace\OneDrive - Zühlke Engineering AG\Documents\master-thesis-code\raw data\sorted\Kurs\EUR_USD Historical Data-ZUEN74390.csv

# %%
filename=str(file).lower().split('\\')[-1]
df=pd.read_csv(file)

# %%
df.isna().sum()
# Out:
# date             0
# price_EUR_USD    0
# month            0
# year             0
# dtype: int64

# %%
df
# Out:
#            date  price_EUR_USD     month  year
# 0     3/26/2021         1.1796     March  2021
# 1     3/25/2021         1.1764     March  2021
# 2     3/24/2021         1.1812     March  2021
# 3     3/23/2021         1.1849     March  2021
# 4     3/22/2021         1.1931     March  2021
# ...         ...            ...       ...   ...
# 4995   2/1/2002         0.8621  February  2002
# 4996  1/31/2002         0.8585   January  2002
# 4997  1/30/2002         0.8617   January  2002
# 4998  1/29/2002         0.8655   January  2002
# 4999  1/28/2002         0.8627   January  2002
#
# [5000 rows x 4 columns]

# %%
df.rename({'Unnamed: 3':'month','Unnamed: 4':'year'}, inplace=True, axis=1)

# %%
df.columns
# Out:
# Index(['date', 'price_EUR_RSD', 'vol_EUR_RSD', 'month', 'year'], dtype='object')

# %%
df['vol_EUR_RSD']=df.vol_EUR_RSD*1000

# %%
df.dtypes
# Out:
# date              object
# price_EUR_RSD    float64
# vol_EUR_RSD      float64
# month             object
# year               int64
# dtype: object

# %%
a=df.groupby(['month','year']).apply(lambda g: g.mean(skipna=False))
# Out:
# C:\Users\mace\AppData\Local\Temp\ipykernel_17916\3890950884.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   a=df.groupby(['month','year']).apply(lambda g: g.mean(skipna=False))

# %%
df.groupby(['month','year'])[['price_EUR_RSD','vol_EUR_RSD']].mean( skipna=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [54], in <cell line: 1>()
# ----> 1 df.groupby(['month','year'])[['price_EUR_RSD','vol_EUR_RSD']].mean( skipna=True)
#
# TypeError: mean() got an unexpected keyword argument 'skipna'

# %%
a.to_csv('eur_usd_proba.csv')

# %%
df['vol_EUR_RSD']=pd.to_numeric(df['vol_EUR_RSD'])

# %%
file=struktura_list.pop()
print(file)
# Out:
# C:\Users\mace\OneDrive - Zühlke Engineering AG\Documents\master-thesis-code\raw data\sorted\Narodna Banka Srbije\used - Copy\osnovni monetarni agregati monthly.csv

# %%
filename=str(file).lower().split('\\')[-1]
df_monetarni_agregati=pd.read_csv(file)

# %%
df_monetarni_agregati.head()
# Out:
#    year     month  Gotov novac u opticaju  Bankarske dinarske rezerve kod NBS  \
# 0  2002     April                 32048.0                             16821.0
# 1  2002    August                 37816.0                             20184.0
# 2  2002  December                 43719.0                             25732.0
# 3  2002  February                 30659.0                             14804.0
# 4  2002   January                 25984.0                             13882.0
#
#    Dinarski primarni novac  Ukupni primarni novac       M1        M2  \
# 0                  49072.0               76477.44  70080.6   79313.0
# 1                  58200.0               86500.38  90160.6  101989.1
# 2                  69543.0              101908.00  93815.0  110896.0
# 3                  45647.0               65464.97  63846.6   71632.0
# 4                  40022.0               59276.21  54643.1   61789.5
#
#          M3  Devizne rezerve NBS u milionima evra  \
# ...

# %%
df_monetarni_agregati.shape
# Out:
# (223, 11)

# %%
new_df = pd.merge(df_struktura_stednje, df_monetarni_agregati,  how='outer', left_on=['Godina','Mesec'], right_on = ['year','month'])

# %%
new_df.head()
# Out:
#    Godina     Mesec  Dinarska i devizno indeksirana štednja-Do pet godina  \
# 0  2008.0    August                                              466.0
# 1  2008.0  December                                              467.0
# 2  2008.0      July                                              450.0
# 3  2008.0  November                                              509.0
# 4  2008.0   October                                              423.0
#
#    Dinarska i devizno indeksirana štednja-Preko pet godina  \
# 0                                              122.0
# 1                                              127.0
# 2                                              124.0
# 3                                              132.0
# 4                                              132.0
#
#    Devizna štednja-Do pet godina  Devizna štednja-Preko pet godina    year  \
# 0                        18411.0                           15578.0  2008.0
# ...

# %%
new_df.shape
# Out:
# (247, 17)

# %%
new_df.drop(['Godina','Mesec'], axis=1, inplace=True)

# %%
new_df.head()
# Out:
#    Dinarska i devizno indeksirana štednja-Do pet godina  \
# 0                                              466.0
# 1                                              467.0
# 2                                              450.0
# 3                                              509.0
# 4                                              423.0
#
#    Dinarska i devizno indeksirana štednja-Preko pet godina  \
# 0                                              122.0
# 1                                              127.0
# 2                                              124.0
# 3                                              132.0
# 4                                              132.0
#
#    Devizna štednja-Do pet godina  Devizna štednja-Preko pet godina    year  \
# 0                        18411.0                           15578.0  2008.0
# 1                        19653.0                           17819.0  2008.0
# 2                        18632.0                           14540.0  2008.0
# ...

# %%
path = "C:\\Users\\mace\\OneDrive - Zühlke Engineering AG\\Documents\\master-thesis-code\\raw data\\sorted\\Kurs\\"
filelist = []

for root, dirs, files in os.walk(path):
    for file in files:
        filelist.append(os.path.join(root, file))
        
for file in filelist:
    if 'plat' in str(file).lower():
        print(str(file).lower())
        filename=str(file).lower().split('\\')[-1]
        df=pd.read_csv(file,skiprows=5, error_bad_lines=False)
        break
        
struktura_list=[a for a in filelist]

# %%
file=struktura_list.pop()
print(file)
# Out:
# C:\Users\mace\OneDrive - Zühlke Engineering AG\Documents\master-thesis-code\raw data\sorted\Kurs\EUR_USD Historical Data-ZUEN74390.csv

# %%
filename=str(file).lower().split('\\')[-1]
df_eur_rsd=pd.read_csv(file)

# %%
df_eur_rsd.head()
# Out:
#          date  price_EUR_USD vol_EUR_USD
# 0  26/03/2021         1.1796     101.87K
# 1  25/03/2021         1.1764     109.83K
# 2  24/03/2021         1.1812     124.61K
# 3  23/03/2021         1.1849      94.56K
# 4  22/03/2021         1.1931      99.73K

# %%
df_eur_rsd.shape
# Out:
# (5000, 3)

# %%
df_eur_rsd.dtypes
# Out:
# date              object
# price_EUR_USD    float64
# vol_EUR_USD       object
# dtype: object

# %%
df_eur_rsd['date']=df_eur_rsd.date.apply(pd.to_datetime)
# Out:
# C:\Users\mace\Anaconda3\lib\site-packages\pandas\core\apply.py:1137: UserWarning: Parsing '26/03/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\mace\Anaconda3\lib\site-packages\pandas\core\apply.py:1137: UserWarning: Parsing '25/03/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\mace\Anaconda3\lib\site-packages\pandas\core\apply.py:1137: UserWarning: Parsing '24/03/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\mace\Anaconda3\lib\site-packages\pandas\core\apply.py:1137: UserWarning: Parsing '23/03/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# ...

# %%
df_eur_rsd.dtypes
# Out:
# date             datetime64[ns]
# price_EUR_USD           float64
# vol_EUR_USD              object
# dtype: object

# %%
df_eur_rsd['month'] = df_eur_rsd['date'].dt.month_name(locale='English')

# %%
df_eur_rsd['year'] = df_eur_rsd['date'].dt.year

# %%
df_eur_rsd.head()
# Out:
#         date  price_EUR_USD vol_EUR_USD  month  year
# 0 2021-03-26         1.1796     101.87K  March  2021
# 1 2021-03-25         1.1764     109.83K  March  2021
# 2 2021-03-24         1.1812     124.61K  March  2021
# 3 2021-03-23         1.1849      94.56K  March  2021
# 4 2021-03-22         1.1931      99.73K  March  2021

# %%
df_eur_rsd['vol_EUR_USD']=df_eur_rsd.vol_EUR_USD.str.replace('K','')
df_eur_rsd['vol_EUR_USD']=pd.to_numeric(df_eur_rsd['vol_EUR_USD'])

# %%
df_eur_rsd['vol_EUR_USD']=pd.to_numeric(df_eur_rsd['vol_EUR_USD'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\Anaconda3\lib\site-packages\pandas\_libs\lib.pyx:2315, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "101.87K"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Input In [76], in <cell line: 1>()
# ----> 1 df_eur_rsd['vol_EUR_USD']=pd.to_numeric(df_eur_rsd['vol_EUR_USD'])
#
# File ~\Anaconda3\lib\site-packages\pandas\core\tools\numeric.py:184, in to_numeric(arg, errors, downcast)
#     182 coerce_numeric = errors not in ("ignore", "raise")
#     183 try:
# --> 184     values, _ = lib.maybe_convert_numeric(
#     185         values, set(), coerce_numeric=coerce_numeric
#     186     )
#     187 except (ValueError, TypeError):
#     188     if errors == "raise":
#
# ...

# %%
df_eur_rsd.groupby(pd.PeriodIndex(df_eur_rsd['date'], freq="M"))[['price_EUR_USD']].mean()
# Out:
#          price_EUR_USD
# date
# 2002-01       0.909875
# 2002-02       0.903805
# 2002-03       0.906165
# 2002-04       0.915090
# 2002-05       0.930200
# ...                ...
# 2021-08       1.203633
# 2021-09       1.200750
# 2021-10       1.202050
# 2021-11       1.208700
# 2021-12       1.209233
#
# [240 rows x 1 columns]

# %%
df_eur_rsd.groupby(pd.PeriodIndex(df_eur_rsd['date'], freq="M"))[['vol_EUR_USD']].mean()
# Out:
# C:\Users\mace\AppData\Local\Temp\ipykernel_15600\790047089.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   df_eur_rsd.groupby(pd.PeriodIndex(df_eur_rsd['date'], freq="M"))[['vol_EUR_USD']].mean()
# Empty DataFrame
# Columns: []
# ...

# %%
new_df=new_df.merge(df_eur_rsd, how='outer', on=['month', 'year'])

# %%
new_df
# Out:
#       Dinarska i devizno indeksirana štednja-Do pet godina  \
# 0                                                 466.0
# 1                                                 466.0
# 2                                                 466.0
# 3                                                 466.0
# 4                                                 466.0
# ...                                                 ...
# 5019                                                NaN
# 5020                                                NaN
# 5021                                                NaN
# 5022                                                NaN
# 5023                                                NaN
#
#       Dinarska i devizno indeksirana štednja-Preko pet godina  \
# 0                                                 122.0
# 1                                                 122.0
# 2                                                 122.0
# ...
